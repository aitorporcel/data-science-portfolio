# %% [markdown]
# # Visualizing the gender gap in college degrees

# %% [markdown]
# ## Introduction

# %% [markdown]
# [The Department of Education Statistics](https://nces.ed.gov/programs/digest/2013menu_tables.asp) releases a data set annually containing the percentage of bachelor's degrees granted to women from 1970 to 2011. The data set is broken up into 17 categories of degrees, with each column as separate category.
# Randal Olson, a data scientist at University of Pennsylvania, has cleaned the data set and made it available on his personal website. One can download the Randal's dataset compiled [here](http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv).
#
# In this project we'll explore the data set of Randal Olson to analyze the gender gap using data visualization.

# %% [markdown]
# First we'll print the first five rows and then plot a few categories of the data set to explore it:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0)
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ## Comparign across all degrees

# %% [markdown]
# Now we will analyze the seventeen degrees in the data set, using a subplot grid layout of 6 rows by 3 columns.
# And then we will be able to group the degrees into STEM, liberal arts, and other in the following way:
#
# **stem_cats** = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
#
# **lib_arts_cats** = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
#
# **other_cats** = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science',
             'Engineering']

lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration',
              'Education', 'Agriculture','Business',
              'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16, 20))

#Generating the first column for stem_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0)
    
    if sp == 0:
        ax.text(2005, 82, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 5:
        ax.text(2007, 90, 'Men')
        ax.text(2005, 5, 'Women')
        
#Generating the first column for lib_arts_cats:
for sp in range(0,5):
    ax = fig.add_subplot(6,3,(sp*3)+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0)
    
    if sp == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 22, 'Men')
    elif sp == 4:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 38, 'Women')   

#Generating the first column for other_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[other_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0)
    
    if sp == 0:
        ax.text(2005, 90, 'Women')
        ax.text(2007, 6, 'Men')
    elif sp == 5:
        ax.text(2007, 65, 'Men')
        ax.text(2005, 35, 'Women')

plt.show()

# %% [markdown]
# ## Hiding x-axis labels

# %% [markdown]
# With seventeen line charts in one diagram, the non-data elements quickly clutter the field of view. The most immediate issue that sticks out is the titles of some line charts overlapping with the x-axis labels for the line chart above it. Because of that, we'll remove the x-axis labels for every line chart in a column except for the bottom most one.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science',
             'Engineering']

lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration',
              'Education', 'Agriculture','Business',
              'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16, 20))

#Generating the first column for stem_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    
    if sp == 0:
        ax.text(2005, 82, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 5:
        ax.text(2007, 90, 'Men')
        ax.text(2005, 5, 'Women')
        ax.tick_params(labelbottom = True)
        
#Generating the first column for lib_arts_cats:
for sp in range(0,5):
    ax = fig.add_subplot(6,3,(sp*3)+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    
    if sp == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 22, 'Men')
    elif sp == 4:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 38, 'Women')
        ax.tick_params(labelbottom = True)


#Generating the first column for other_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[other_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    
    if sp == 0:
        ax.text(2005, 90, 'Women')
        ax.text(2007, 6, 'Men')
    elif sp == 5:
        ax.text(2007, 65, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom = True)

plt.show()

# %% [markdown]
# ## Setting y-axis labels

# %% [markdown]
# In the vein of reducing cluttering, let's also simplify the y-axis labels. Currently, all seventeen plots have six y-axis labels and even though they are consistent across the plots, they still add to the visual clutter. By keeping just the starting and ending labels (0 and 100), we can keep some of the benefits of having the y-axis labels to begin with.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science',
             'Engineering']

lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration',
              'Education', 'Agriculture','Business',
              'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16, 20))

#Generating the first column for stem_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    
    if sp == 0:
        ax.text(2005, 82, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 5:
        ax.text(2007, 90, 'Men')
        ax.text(2005, 5, 'Women')
        ax.tick_params(labelbottom = True)
        
#Generating the first column for lib_arts_cats:
for sp in range(0,5):
    ax = fig.add_subplot(6,3,(sp*3)+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    
    if sp == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 22, 'Men')
    elif sp == 4:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 38, 'Women')
        ax.tick_params(labelbottom = True)


#Generating the first column for other_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[other_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    
    if sp == 0:
        ax.text(2005, 90, 'Women')
        ax.text(2007, 6, 'Men')
    elif sp == 5:
        ax.text(2007, 65, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom = True)

plt.show()

# %% [markdown]
# # Adding a horizontal line

# %% [markdown]
# While removing most of the y-axis labels definitely reduced clutter, it also made it hard to understand which degrees have close to 50-50 gender breakdown. While keeping all of the y-axis labels would have made it easier, we can actually do one better and use a horizontal line across all of the line charts where the y-axis label 50 would have been.

# %% [markdown]
# We'll use the next color in the Color Blind 10 palette for this horizontal line, which has an RGB value of (171, 171, 171). Because we don't want this line to clutter the viewing experience, let's increase the transparency of the line, using the c parameter for the color and the alpha parameter for transparency.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science',
             'Engineering']

lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration',
              'Education', 'Agriculture','Business',
              'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16, 20))

#Generating the first column for stem_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 82, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 5:
        ax.text(2007, 90, 'Men')
        ax.text(2005, 5, 'Women')
        ax.tick_params(labelbottom = True)
        
#Generating the first column for lib_arts_cats:
for sp in range(0,5):
    ax = fig.add_subplot(6,3,(sp*3)+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 22, 'Men')
    elif sp == 4:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 38, 'Women')
        ax.tick_params(labelbottom = True)


#Generating the first column for other_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[other_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 90, 'Women')
        ax.text(2007, 6, 'Men')
    elif sp == 5:
        ax.text(2007, 65, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom='on')

plt.show()

# %% [markdown]
# ## Exporting to a file

# %% [markdown]
# Finally we'll export the figure containing all of the line charts to "gender:degrees.png"

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics',
             'Physical Sciences', 'Computer Science',
             'Engineering']

lib_arts_cats = ['Foreign Languages', 'English',
                 'Communications and Journalism',
                 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration',
              'Education', 'Agriculture','Business',
              'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16, 20))

#Generating the first column for stem_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[stem_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 82, 'Women')
        ax.text(2007, 12, 'Men')
    elif sp == 5:
        ax.text(2007, 90, 'Men')
        ax.text(2005, 5, 'Women')
        ax.tick_params(labelbottom = True)
        
#Generating the first column for lib_arts_cats:
for sp in range(0,5):
    ax = fig.add_subplot(6,3,(sp*3)+2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[lib_arts_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 78, 'Women')
        ax.text(2007, 22, 'Men')
    elif sp == 4:
        ax.text(2007, 60, 'Men')
        ax.text(2005, 38, 'Women')
        ax.tick_params(labelbottom = True)


#Generating the first column for other_cats:
for sp in range(0,6):
    ax = fig.add_subplot(6,3,(sp*3)+3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], 
            c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'],
            100-women_degrees[other_cats[sp]],
            c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(axis = "both", which = "both", length = 0, labelbottom = False)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    
    if sp == 0:
        ax.text(2005, 90, 'Women')
        ax.text(2007, 6, 'Men')
    elif sp == 5:
        ax.text(2007, 65, 'Men')
        ax.text(2005, 35, 'Women')
        ax.tick_params(labelbottom = True)


plt.savefig("gender_degrees.png")
plt.show()
